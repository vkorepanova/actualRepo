# %% [markdown]
# ## Задача 1

# %%
import math

class Complex:
    def __init__(self, a, b):
        self.a = a
        self.b = b
     
    def __str__(self):
        return '%s + %si' % (self.a, self.b)

    def __add__(self, rhs):
        return (Complex(self.a + rhs.a, self.b + rhs.b))
    
    def __abs__(self):
        return math.sqrt(self.a**2 + self.b**2)
    
    def __sub__(self, rhs):
        return Complex(self.a - rhs.a, self.b - rhs.b)
    
    def __mul__(self, rhs):
        return Complex((self.a*rhs.a - self.b*rhs.b), (self.a*rhs.b + self.b*rhs.a))
    
if __name__ == "__main__":
    a = Complex(0, 1)
    b = Complex(2, 3)
    c = Complex(4, 5)
    print(a+b+c)
    print(a-b)
    print(a*b)                   
    print(abs(a))
    print(abs(b))
# Out:
# 6 + 9i
# -2 + -2i
# -3 + 2i
# 1.0
# 3.605551275463989

# %% [markdown]
# ## Задача 2

# %%
import math

# def sum(vectors):
#     if not len(vectors):
#         return Vector(None, None, None)
    
#     output = None
#     for vector in vectors:
#         if not output:
#             output = vectors[0]
#         output += vector
#     return output

# class list(list):
    
#     def __add__(self, other):
#         if isinstance(other, int) and all(isinstance(_, Vector) for _ in self):
#             print('log')
#             return Vector(0, 0, 0)
        
#         return super().__add__(other)
    
#     def __truediv__(self, other):
#         if isinstance(other, int) and not any(isinstance(_, Vector) for _ in self):
#             return 
    

class Vector:
    
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        
    def __str__(self):
        return 'Vector(%s, %s, %s)' % (self.x, self.y, self.z)
    
    def distance(self, x, y, z):
        return math.sqrt(self.x**2 + self.y**2 + self.z**2)
    
#     def __add__(self, rhs):
#         if isinstance(rhs, int):
#             return self
#         return Vector(self.x+rhs.x, self.y+rhs.y, self.z + rhs.z)
    
#     def __radd__(self, rhs):
#         if isinstance(rhs, int):
#             return self
#         return Vector(self.x+rhs.x, self.y+rhs.y, self.z + rhs.z)
    
#     def __iadd__(self, rhs):
#         if isinstance(rhs, int):
#             return self
#         self.x += rhs.x
#         self.y += rhs.y
#         self.z += rhs.z
        
#         return self
    
#     def __truediv__(self, rhs):
#         if isinstance(rhs, int):
#             Vector(self.x / rhs, self.y / rhs, self.z / rhs)
#         return self
    
#     def __rtruediv__(self, rhs):
#         if isinstance(rhs, int):
#             Vector(self.x / rhs, self.y / rhs, self.z / rhs)
#         return self
    
#     def __itruediv__(self, rhs):
#         if isinstance(rhs, int):
#             Vector(self.x / rhs, self.y / rhs, self.z / rhs)
#         return self
    
    @staticmethod
    def centre(vectors):
        print(vectors)
        sum_v = sum(vectors)
        print(sum_v)
        centre = sum_v / len(vectors)
        return centre
    
k = {}    
if __name__ == "__main__":
    print("Введи число N:", end = '')
    N = int(input())
    vectors = list()
    for i in range(N):
        _vector = input().split()
        x = int(_vector[0])
        y = int(_vector[1])
        z = int(_vector[2])
        answer = Vector(x, y, z)
        vectors.append(answer)
        k[(x, y, z)] = answer.distance(x, y, z)
    print(max(k))
    print(Vector.centre(vectors))
# Out:
# Введи число N:2
# 1 1 1
# 2 2 2
# (2, 2, 2)
# [<__main__.Vector object at 0x0000022731694E88>, <__main__.Vector object at 0x000002273176BB08>]
# Vector(4, 4, 4)
# Vector(4, 4, 4)

# %%
import math

class Vector:
    
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        
    def __str__(self):
        return 'Vector(%s, %s, %s)' % (self.x, self.y, self.z)
    
    def distance(self, x, y, z):
        return math.sqrt(self.x**2 + self.y**2 + self.z**2)
    
    def area(self, x, y, z):
        return 

def angle(a, b):
    cos = (a[0]*b[0]+a[1]*b[1]+a[2]*b[2])/(math.sqrt(a[0]+a[1]+a[2])*math.sqrt(b[0]+b[1]+b[2]))
    sin = math.sqrt(1-cos**2)
    return sin 
    
if __name__ == "__main__":
    v1 = input().split()
    v2 = input().split()
    vectors = []
    for i in range(2):
        v = input().split()
        x = int(v[0])
        y = int(v[1])
        z = int(v[2])
